# %% [markdown]
# # Atividade 1 — Exercícios com os comandos básicos de pandas para EDA
#
#
# Responda as perguntas abaixo no notebook (cada resposta deve ter ao menos uma célula de código que produza o output e, logo abaixo, uma célula de texto com a sua interpretação).

# %% [markdown]
# ## 1) Carregue o dataset e mostre as primeiras 10 linhas.

# %%
import pandas as pd
url = "https://drive.google.com/uc?export=download&id=1eJ-L0MnJxHi929fZrVOKxH7Mrw5eTGpk"
Df = pd.read_csv(url)
Df.head(10)
# Out:
# /tmp/ipykernel_539/1694070970.py:3: DtypeWarning: Columns (0,3,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   Df = pd.read_csv(url)
#   Código da Emenda  Ano da Emenda  \
# 0   Sem informação           2014
# 1   Sem informação           2014
# 2   Sem informação           2014
# 3   Sem informação           2014
# 4   Sem informação           2014
# 5   Sem informação           2014
# 6   Sem informação           2014
# 7   Sem informação           2014
# 8   Sem informação           2014
# 9   Sem informação           2014
#
#                                       Tipo de Emenda  \
# 0  Emenda Individual - Transferências com Finalid...
# 1  Emenda Individual - Transferências com Finalid...
# 2  Emenda Individual - Transferências com Finalid...
# 3  Emenda Individual - Transferências com Finalid...
# 4  Emenda Individual - Transferências com Finalid...
# 5  Emenda Individual - Transferências com Finalid...
# ...

# %% [markdown]
# Explique em uma frase o que você observa nas primeiras 10 linhas.
# As primeiras 10 linhas mostram registros de emendas individuais do ano de 2014, adicionando informações como a localização pra onde os recurso foram direcionados, a finalidade de tais orçamentos e como foi feita a execução desse ponto de vista financeiro.

# %% [markdown]
# ## 2) Quantas linhas e colunas o dataset possui?

# %%
Df.shape
# Out:
# (88596, 28)

# %% [markdown]
# Os números representam a quantidade de linhas (registro) e colunas (característica/variável) do dataset. São 88596 linhas e 28 colunas.

# %% [markdown]
# ## 3) Liste os nomes das colunas e descreva brevemente o que você entende que cada coluna representa.

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88596 entries, 0 to 88595
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Código da Emenda                    88596 non-null  object
#  1   Ano da Emenda                       88596 non-null  int64
#  2   Tipo de Emenda                      88596 non-null  object
#  3   Código do Autor da Emenda           88596 non-null  object
#  4   Nome do Autor da Emenda             88596 non-null  object
#  5   Número da emenda                    88596 non-null  object
#  6   Localidade de aplicação do recurso  88596 non-null  object
#  7   Código Município IBGE               88596 non-null  object
#  8   Município                           88596 non-null  object
#  9   Código UF IBGE                      88596 non-null  int64
#  10  UF                                  88596 non-null  object
# ...

# %% [markdown]
# Com o comando df.info pode visualizar que este conjunto de dados contém 88.596 registros e 28 colunas estruturado da seguinte maneira:
# - Identificação e autoria
# - Geolocalização
# - Classificação Orrçamentária
# - Ciclo Financeiro.

# %% [markdown]
# ## 4) Existem valores nulos? quantos?

# %%
nulos = Df.isnull().sum()
nulos
# Out:
# Código da Emenda                      0
# Ano da Emenda                         0
# Tipo de Emenda                        0
# Código do Autor da Emenda             0
# Nome do Autor da Emenda               0
# Número da emenda                      0
# Localidade de aplicação do recurso    0
# Código Município IBGE                 0
# Município                             0
# Código UF IBGE                        0
# UF                                    0
# Região                                0
# Código Função                         0
# Nome Função                           0
# Código Subfunção                      0
# Nome Subfunção                        0
# Código Programa                       0
# Nome Programa                         0
# Código Ação                           0
# Nome Ação                             0
# Código Plano Orçamentário             0
# Nome Plano Orçamentário               0
# Valor Empenhado                       0
# ...

# %% [markdown]
# O dataset não apresenta dados ausentes (nulos).

# %% [markdown]
# ## 5) Mostre os tipos das variáveis (se int, string, boolean, float...) e analise se alguma variável parece ter o tipo errado. Faça isso da maneira mais objetiva e otimizada possível.

# %%
Df.dtypes
# Out:
# Código da Emenda                      object
# Ano da Emenda                          int64
# Tipo de Emenda                        object
# Código do Autor da Emenda             object
# Nome do Autor da Emenda               object
# Número da emenda                      object
# Localidade de aplicação do recurso    object
# Código Município IBGE                 object
# Município                             object
# Código UF IBGE                         int64
# UF                                    object
# Região                                object
# Código Função                         object
# Nome Função                           object
# Código Subfunção                      object
# Nome Subfunção                        object
# Código Programa                       object
# Nome Programa                         object
# Código Ação                           object
# Nome Ação                             object
# Código Plano Orçamentário             object
# ...

# %% [markdown]
# Se alguma coluna estiver com o tipo errado, escreva abaixo qual é e por que isso pode atrapalhar análises.
#
# Divergência de Tipos: As colunas de execução financeira (ex: Valor Empenhado, Valor Pago) estão classificadas como object (string), quando deveriam ser float64 (numéricas)
#
# Impacto Técnico: o Phyton entende que tais valores são texto, esta configuração inviabiliza cálculos matemáticos, agregações estatísticas e a plotagem correta de gráficos.

# %% [markdown]
# ## 6) Usando a coluna `Ano da Emenda` como base, descubra até que ano o dataset está atualizado (mostre as 8 primeiras linhas do df ordenado desc).

# %%
Df = Df.sort_values(by='Ano da Emenda', ascending=False)
Df.head(8)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 88564     202541820003           2025
# 88578     202544940001           2025
# 88595     202544840009           2025
# 88594     202544840008           2025
# 88577     202541820017           2025
# 88576     202541820016           2025
# 88575     202541820015           2025
# 88574     202541820014           2025
#
#                                           Tipo de Emenda  \
# 88564       Emenda Individual - Transferências Especiais
# 88578  Emenda Individual - Transferências com Finalid...
# 88595  Emenda Individual - Transferências com Finalid...
# 88594  Emenda Individual - Transferências com Finalid...
# 88577  Emenda Individual - Transferências com Finalid...
# 88576  Emenda Individual - Transferências com Finalid...
# 88575  Emenda Individual - Transferências com Finalid...
# 88574  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# ...

# %% [markdown]
# Explique: qual o ano mais recente presente no dataset?
#
# O dataset está atualizado até o ano de 2025.

# %% [markdown]
# ## 7) execute um  `describe()` e explique uma conclusão simples que você consegue tirar a partir das estatísticas (se algumas colunas deveriam aparecer no describe mas não aparecem, indique o motivo que você acredita que esteja causando esse problema).

# %%
Df.describe()
# Out:
#        Ano da Emenda  Código UF IBGE
# count   88596.000000    8.859600e+04
# mean     2019.155109    2.943594e+06
# std         3.409323    1.264884e+06
# min      2014.000000   -1.400000e+01
# 25%      2016.000000    2.300000e+06
# 50%      2019.000000    3.100000e+06
# 75%      2022.000000    3.500000e+06
# max      2025.000000    5.300000e+06

# %% [markdown]
# O describe() mostra que o dataset cobrem um período de 11 anos (de 2014 a 2025). A média e a mediana (50%) estão em torno de 2019, o que indica que o volume de emendas possui uma boa distribuição temporal (2014-2025), mas revela uma falha na tipagem: as variáveis financeiras não aparecem no resumo estatístico por estarem classificadas como object (texto).

# %% [markdown]
# ## 8) Mostre as últimas 5 linhas do dataset e escreva se a última linha parece completa (sem muitos nulos) ou não.

# %%
Df.tail()
# Out:
#      Código da Emenda  Ano da Emenda  \
# 7466   Sem informação           2014
# 7467   Sem informação           2014
# 7468   Sem informação           2014
# 7469   Sem informação           2014
# 7459   Sem informação           2014
#
#                                          Tipo de Emenda  \
# 7466  Emenda Individual - Transferências com Finalid...
# 7467  Emenda Individual - Transferências com Finalid...
# 7468  Emenda Individual - Transferências com Finalid...
# 7469  Emenda Individual - Transferências com Finalid...
# 7459  Emenda Individual - Transferências com Finalid...
#
#      Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 7466                       S/I          Sem informação              S/I
# 7467                       S/I          Sem informação              S/I
# 7468                       S/I          Sem informação              S/I
# 7469                       S/I          Sem informação              S/I
# ...

# %% [markdown]
# Interprete a completude da última linha.

# %% [markdown]
# Embora não existam buracos, a última linha, por exemplo, contém termos como "Sem informação" e "S/I". Para o Python, isso conta como "preenchido" (porque tem texto escrito), mas para análise, isso é um dado faltante mascarado.

# %% [markdown]
# ## 9) existem valores duplicados no dataframe? Caso positivo, quantos?

# %%
Duplicatas = Df.duplicated().sum()
print(Duplicatas)
# Out:
# 0

# %% [markdown]
# Não existem valores duplicados no dataframe.
